# %% [markdown]
# <a href="https://colab.research.google.com/github/ximena26041636/Fundamentos/blob/main/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
X = "Carlos"
variableBooleana= True
print("Hola", x, X, "X", variableBooleana)
# Out:
# Hola 5 Carlos X

# %%
numero1 = 20
numero2 = 40
if numero1 > numero2:
  print("El numero", numero1, "es mayor que", numero2)
elif numero1 == numero2
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
#   File "/tmp/ipykernel_2549/868836349.py", line 5
#     elif numero1 == numero2
#                            ^
# SyntaxError: expected ':'
