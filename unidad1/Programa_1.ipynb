# %% [markdown]
# <a href="https://colab.research.google.com/github/ximena26041636/Fundamentos/blob/main/unidad1/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ingenieria en Inteligencia Artificial**
# # **Fundamentos de Programacion**
# ## **Unidad 1**
# ### Practica 1: Introduccion al lenguaje de programacion Python
# Docente: **Jose Gabriel Rodriguez Rivas**
# ALumno: **Ximena Gonzalez Castro**
# Numero de control: **26041636**

# %%
s = None # Inicializa 's' para evitar el NameError, o asigna un valor relevante si es necesario.
x = s
x = "hola mundo"
x = True
print("el valor de x es", x) # Se corrigió 'Print' a 'print'
# Out:
# el valor de x es True

# %%
base = input("Dame la base de triangulo")
altura = input("Dame la altura del triangulo")
area = (int(base)*int(altura))/2
print("El area del triangulo es", area)
# Out:
# Dame la base de triangulo10
# Dame la altura del triangulo20
# El area del triangulo es 100.0

# %%
numero1 = 20
numero2 = 40
if numero1 > numero2:
  print("El numero", numero1, "es mayor que", numero2)
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
# El numero 40 es mayor que 20

# %%
x = 5
X = "Carlos"
variableBooleana= True
print("Hola", x, X, "X", variableBooleana)
# Out:
# Hola 5 Carlos X True

# %%
numero1 = 40
numero2 = 40
if numero1 > numero2:
  print("El numero", numero1, "es mayor que", numero2)
elif numero1 == numero2:
  print("Ambos numeros son iguales")
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
# Ambos numeros son iguales

# %%
tabla = 5
for i in range(1,11,2):
  print(tabla,"x",i,"=", tabla*i)
# Out:
# 5 x 1 = 5
# 5 x 3 = 15
# 5 x 5 = 25
# 5 x 7 = 35
# 5 x 9 = 45

# %%
edad = int(input("dime tu edad"))
if edad <= 10:
  print("eres un infante")
elif edad <= 18:
    print("eres un adolecente")
elif edad <= 30:
    print("eres un adulto joven")
elif edad <= 65:
    print("eres un adulto")
else:
    print("eres un adulto mayor")
# Out:
# dime tu edad10
# eres un infante

# %%
z = 10
a = "Hola"
print(z*a)
# Out:
# HolaHolaHolaHolaHolaHolaHolaHolaHolaHola

# %%
10>5 or 5>10
# Out:
# True

# %%
5>10
# Out:
# False

# %%
tabla = int(input("¿Que tabla de multiplicar quieres?"))
limiteinicial= int(input("dame liomite incial"))
limitefinal=int(input("dame limite final"))
incrementos=int(input("dame el numero de incremento"))
for i in range(limiteinicial,limitefinal,incrementos):
  print(tabla,"x",i,"=",tabla*i)
# Out:
# ¿Que tabla de multiplicar quieres?10
# dame liomite incial10
# dame limite final20
# dame el numero de incremento2
# 10 x 10 = 100
# 10 x 12 = 120
# 10 x 14 = 140
# 10 x 16 = 160
# 10 x 18 = 180

# %%
tabla = 8
for i in range(1,11, 2):
    print( tabla, "x", i, "=", tabla*i)
# Out:
# 8 x 1 = 8
# 8 x 3 = 24
# 8 x 5 = 40
# 8 x 7 = 56
# 8 x 9 = 72

# %%
variable1 = 70
variable2 = 50
if variable1 > variable2:
  print( variable1,"es mayor que", variable2)
else:
  print(variable2,"es mayor que", variable1)
# Out:
# 70 es mayor que 50

# %%
10 > 5 and 5 > 10
# Out:
# False

# %%
#en este caso esta mal implementada la logica por que
#al ser if´s independiente se van a evaluar cada una de ellas
#y si ponemos por ejemplo
edad= int(input("dame tu edad"))
if edad>= 65:
  print("eres un adulto")
elif edad >= 30:
  print("eres un adulto joven")
elif edad >= 18:
  print("eres un adolcente")
elif edad >= 10:
  print("eres un infante")
else:
  print("eres un anciano")
# Out:
# dame tu edad29
# eres un adolcente

# %%
numero = 1
while numero<= 5:
  print(numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Tema de listas**

# %%
alumnos =["ana", "luis","carlos", "juan"]
print(alumnos)
print(alumnos[1])
print(alumnos[3])
# Out:
# ['ana', 'luis', 'carlos', 'juan']
# luis
# juan

# %%
# modificar un valor de la lista especifico
alumnos [1]="maria luisa"
print(alumnos)
# Out:
# ['ana', 'maria luisa', 'carlos', 'juan']

# %%
#agrega metodo apped un elemento al final de la lista
alumnos.append("carla")
print(alumnos)
# Out:
# ['ana', 'maria luisa', 'carlos', 'juan', 'carla']

# %%
#el metodo insert agrega un elemento al final de la lista.
alumnos.insert(0,"cristina")
print(alumnos)
# Out:
# ['cristina', 'ana', 'maria luisa', 'carlos', 'juan', 'carla']

# %%
alumnos = ["cristina", "ana", "maria luisa", "carlos", "juan", "carla"]
#remove elimina un elemento especificando el valor del elemento
# debe concidir exactamente mayusculas y minusculas
alumnos.remove("ana")
# alumnos.remove("ana") # This would cause a ValueError as 'ana' is no longer in the list
print(alumnos)
# Out:
# ['cristina', 'maria luisa', 'carlos', 'juan', 'carla']

# %%
print(alumnos)
# Out:
# ['cristina', 'maria luisa', 'carlos', 'juan', 'carla']

# %%
#pop elimina el elemnto o item en la posicion especificada
alumnos.pop(2)
print(alumnos)
# Out:
# ['cristina', 'maria luisa', 'juan', 'carla']

# %%
# del elinmina el elemennto o item en la posicion especificada
del alumnos[3]
print(alumnos)
# Out:
# ['cristina', 'ana', 'maria luisa', 'juan', 'carla']

# %%
print("elemnetos en la lista de alumnos",len(alumnos))# len nos permite conocer los elementos de la lista
# Out:
# elemnetos en la lista de alumnos 5

# %%
alumnos.append("ana")
alumnos.append("ernesto")
for X in alumnos:
 print(X)
# Out:
# cristina
# ana
# maria luisa
# juan
# carla
# ana
# ernesto

# %%
print(alumnos)
for x in alumnos:
  print(X)
  if x=="ana":
    break #breck forza a salir del ciclo siempre y cuando se cumpla
          #la condicion if
# Out:
# ['cristina', 'ana', 'maria luisa', 'juan', 'carla', 'ana', 'ernesto']
# ernesto
# ernesto

# %%
software = ["python","python y vs code","autocad","solidiWorks","java"]
print(software)
# Out:
# ['python', 'python y vs code', 'autocad', 'solidiWorks', 'java']

# %%
if"python" in software:
  print("python esta en la lista de software")
else:
  print("python no esta en la lista de sofrware")
# Out:
# python esta en la lista de software

# %%
alumnos.append("Ana")
alumnos.append("Ernesto")
for x in alumnos:
  print(x)
# Out:
# cristina
# ana
# maria luisa
# juan
# carla
# ana
# ernesto
# Ana
# Ana
# Ernesto

# %%
# ========================================
# SISTEMA DE PRESTAMOS
# Version 1 - Programacion basica y uso de listas
# ========================================

# Lista de alumnos activos en el sistema
alumnos = ["26040200", "26040201", "26040202", "26040203", "26040204"]

# Cada valor en la lista de computadoras tiene su lista correspondiente con el
# Aula donde esta ubicada, el softwareinstalado y el estado de esa computadora
computadoras = ["PC-LC1-01", "PC-LC1-02", "PC-LC1-03",
                "PC-LC2-01", "PC-LC2-02", "PC-LC2-03",
                "PC-LC3-01", "PC-LC3-02", "PC-LC3-03", "PC-LC3-04"]

aulas = ["LC1", "LC1", "LC1",
         "LC2", "LC2", "LC2",
         "LC3", "LC3", "LC3", "LC3"]

software = ["Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Pyhton, Java, VS Code", "AutoCAD, MATLAB",
            "Python, VS Code", "Python, Java, VS Code", "AutoCAD, MATLAB", "Pyhton, VS Code"]

estado = ["Disponible", "Prestada", "Reservada",
          "Disponible", "Prestada", "Reservada",
          "Disponible", "Prestada", "Reservada", "Mantenimiento"]

# MENU PRINCIPAL
# Usamos un ciclo While que se repetira indefinidamente hasta que el usuario
# teclee la opcion 7 (salir) o cualquier numero superior a 7
opcion = 0
while opcion <= 6:
    print("\n================================")
    print("      SISTEMA DE PRESTAMOS")
    print("================================")
    print("1. Consultar computadoras")
    print("2. Buscar software")
    print("3. Solicitar prestamo")
    print("4. Devolver computadora")
    print("5. Crear reservacion")
    print("6. Agregar computadora")
    print("7. Salir")
    print("================================")
    opcion = int(input("Seleccione una opcion: "))

    # 1. Consultar computadoras
    # si el usuario selecciono la opcion 1 se hace un ciclo (for) que recorre
    # toda la lista de computadoras e imprime los valores de las demas listas
    if opcion == 1:
        print("\n--- COMPUTADORAS ---")
        for i in range(len(computadoras)):
            print("Aula:", aulas[i])
            print("ID:", computadoras[i])
            print("Software:", software[i])
            print("Estado:", estado[i])
            print("------------------------")

    # 2. Buscar por software
    elif opcion == 2:
      programa = input("\nIngrese el software que desea buscar: ")
      print("\n--- RESULTADOS ---")
      encontrado = False
      for i in range(len(computadoras)):
          # la funcion (lower) convierte a minuscula el texto, de esta forma
          # nos aseguramos que el texto a buscar y la informacion de las listas
          # este en minuscula y no tengamos problema de que no encuntra un programa
          # porq este escrito de forma diferente usando mayusculas y minusculas
        if programa.lower()  in software[i].lower():
            print("ID:", computadoras[i])
            print("Aula:", aulas[i])
            print("Software:", software[i])
            print("Estado:", estados[i])
            print("------------------------")
            encontrado = True

      if encontrado == False:
        print("No se encontraron computadoras con ese software.")

#3. Solicitar prestamo
    elif opcion== 3:
     print("\n--- SOLICITAR PRESTAMO ---")
  num_control = input("Ingrese el numero de control: ")
  encontrado1 = False
  # Verificar si existe el alumno en la lista o BD
  if num_control in alumnos:
    encontrado1 = True
    # Si existe, continuamos con el procedimiento
    encontrado1 = True
    id_computadora = input("Ingrese el ID de la computadora: ")
    encontrado2 = False
    for i in range(len(computadoras)):
      if id_computadora == computadoras[i]:
        encontrado2 = True
        if estado[i] == "Disponible":
          estado[i] = "Prestada"
          print("Prestamo registrado correctamente.")
          print("Computadora.", computadoras[i])
          print("Aula:", aulas[i])
        else:
          print("Lacomputadora no esta disponible.")
    if encontrado2 == False:
      print("La computadora no existe.")
  if encontrado1 == False:
    print("El alumno no existe.")
